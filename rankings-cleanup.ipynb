# %%
import pandas as pd

# %%
rankings = pd.read_csv('./data/fifa_ranking-2022-10-06.csv')
rankings
# Out:
#        rank  country_full country_abrv  total_points  previous_points  \
# 0         1       Germany          GER         57.00             0.00
# 1        96         Syria          SYR         11.00             0.00
# 2        97  Burkina Faso          BFA         11.00             0.00
# 3        99        Latvia          LVA         10.00             0.00
# 4       100       Burundi          BDI         10.00             0.00
# ...     ...           ...          ...           ...              ...
# 63911    74   El Salvador          SLV       1330.51          1333.48
# 63912    75          Oman          OMA       1320.29          1323.03
# 63913    76        Israel          ISR       1316.55          1316.35
# 63914    78       Georgia          GEO       1307.34          1296.46
# 63915   211    San Marino          SMR        762.22           763.82
#
#        rank_change confederation   rank_date
# 0                0          UEFA  1992-12-31
# 1                0           AFC  1992-12-31
# 2                0           CAF  1992-12-31
# 3                0          UEFA  1992-12-31
# 4                0           CAF  1992-12-31
# ...            ...           ...         ...
# 63911            3      CONCACAF  2022-10-06
# 63912            0           AFC  2022-10-06
# 63913            0          UEFA  2022-10-06
# 63914           -4          UEFA  2022-10-06
# 63915            0          UEFA  2022-10-06
#
# [63916 rows x 8 columns]

# %%
rankings.info()
rankings.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63916 entries, 0 to 63915
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             63916 non-null  int64
#  1   country_full     63916 non-null  object
#  2   country_abrv     63916 non-null  object
#  3   total_points     63916 non-null  float64
#  4   previous_points  63916 non-null  float64
#  5   rank_change      63916 non-null  int64
#  6   confederation    63916 non-null  object
#  7   rank_date        63916 non-null  object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.9+ MB
#                rank  total_points  previous_points   rank_change
# count  63916.000000  63916.000000     63916.000000  63916.000000
# mean     100.196821    442.404780       440.999013      0.004756
# std       58.060019    409.091526       409.321338      5.660809
# min        1.000000      1.000000         0.000000    -92.000000
# 25%       50.000000     88.000000        86.000000     -1.000000
# 50%      100.000000    347.000000       345.000000      0.000000
# 75%      149.000000    641.000000       640.000000      2.000000
# max      211.000000   2172.000000      2187.000000    199.000000

# %% [markdown]
# ## Country_codes load, used for cleaning rankings

# %%
# Using a stadardized table team - fifa_code 
# Use this to clean rankings table
country_codes = pd.read_csv('./data/country_codes.csv')
country_codes
# Out:
#                team code         country
# 0       Afghanistan  AFG     Afghanistan
# 1           Albania  ALB         Albania
# 2           Algeria  ALG         Algeria
# 3    American Samoa  ASA  American Samoa
# 4           Andorra  AND         Andorra
# ..              ...  ...             ...
# 206         Vietnam  VIE         Vietnam
# 207           Wales  WAL  United Kingdom
# 208           Yemen  YEM           Yemen
# 209          Zambia  ZAM          Zambia
# 210        Zimbabwe  ZIM        Zimbabwe
#
# [211 rows x 3 columns]

# %%
# We want to link tables by the code (country_codes) = country_abrv (rankings)
# So check how well they link

# Match the codes in COUNTRY_CODES to the codes in RANKINGS 
print(list(set(country_codes['code'].unique()) - set(rankings['country_abrv'].unique())))
# Out:
# []

# %%
# EXACT MATCH ABOVE

# now match codes in RANKINGS to the codes in COUNTRY_CODES
list(set(rankings['country_abrv'].unique()) - set(country_codes['code'].unique()))
# Out:
# ['YUG', 'ANT', 'SCG', 'ZAI', 'LIB', 'TCH']

# %% [markdown]
# ### We have a few problems, but at least we know all codes in COUNTRY_CODES map to the RANKINGS
# ### So we only need to work on the RANKINGS table to clean the codes above
# ### Also chech the consistency of country naming (country_full) in RANKINGS

# %% [markdown]
# # RANKINGS TABLE CLEANING

# %% [markdown]
# ## Irregular Data
# ### Same fifa_code, different country name variation

# %%
rankings_modif = rankings.copy()

# %%
# Group all countries by the abreviation (which we know is unique)
abvr = rankings_modif['country_full'].groupby(rankings_modif['country_abrv']).unique().apply(pd.Series)
abvr
# Out:
#                         0    1    2
# country_abrv
# AFG           Afghanistan  NaN  NaN
# AIA              Anguilla  NaN  NaN
# ALB               Albania  NaN  NaN
# ALG               Algeria  NaN  NaN
# AND               Andorra  NaN  NaN
# ...                   ...  ...  ...
# YEM                 Yemen  NaN  NaN
# YUG            Yugoslavia  NaN  NaN
# ZAI                 Zaire  NaN  NaN
# ZAM                Zambia  NaN  NaN
# ZIM              Zimbabwe  NaN  NaN
#
# [217 rows x 3 columns]

# %%
abvr_to_fix = abvr[~abvr[1].isnull()]
abvr_to_fix
# Out:
#                                            0                         1  \
# country_abrv
# CPV                       Cape Verde Islands                Cabo Verde
# CUW                                  Curacao                   Curaçao
# MKD                            FYR Macedonia           North Macedonia
# STP                      Sao Tome e Principe       São Tomé e Príncipe
# SWZ                                 Eswatini                 Swaziland
# TUR                                   Turkey                   Türkiye
# VIN           St. Vincent and the Grenadines  St. Vincent / Grenadines
#
#                                   2
# country_abrv
# CPV                             NaN
# CUW                             NaN
# MKD                             NaN
# STP           São Tomé and Príncipe
# SWZ                             NaN
# TUR                             NaN
# VIN                             NaN

# %%
# Indexes to fix
abvr_to_fix[0].index
# Out:
# Index(['CPV', 'CUW', 'MKD', 'STP', 'SWZ', 'TUR', 'VIN'], dtype='object', name='country_abrv')

# %%
# Take indexes countries from COUNTRY_CODE
abvr_to_fix_countries_list = country_codes.loc[country_codes['code'].isin(abvr_to_fix[0].index)]
# Resulting on a subset of that table, with the indexes and the names we want
abvr_to_fix_countries_list
# Out:
#                                  team code                           country
# 36                         Cape Verde  CPV                        Cape Verde
# 50                            Curaçao  CUW                           Curaçao
# 65                           Eswatini  SWZ                          Eswatini
# 139                   North Macedonia  MKD                   North Macedonia
# 160  Saint Vincent and the Grenadines  VIN  Saint Vincent and the Grenadines
# 163             São Tomé and Príncipe  STP             São Tomé and Príncipe
# 194                            Turkey  TUR                            Turkey

# %%
abvr_to_fix_countries_list[abvr_to_fix_countries_list['code']=='CPV']['team'].values[0]
# Out:
# 'Cape Verde'

# %%
# Iterate through the list of indexes
for index in abvr_to_fix[0].index:
    # Select the value of one column based on the condition that another column (country_abrevation) is some index
    # Assign to the value, the correct team name taken from the COUNTRY_CODES table 
    rankings_modif.loc[rankings_modif['country_abrv'] == index, 'country_full'] = abvr_to_fix_countries_list[abvr_to_fix_countries_list['code'] == index]['team'].values[0]

# %%
rankings_modif
# Out:
#        rank  country_full country_abrv  total_points  previous_points  \
# 0         1       Germany          GER         57.00             0.00
# 1        96         Syria          SYR         11.00             0.00
# 2        97  Burkina Faso          BFA         11.00             0.00
# 3        99        Latvia          LVA         10.00             0.00
# 4       100       Burundi          BDI         10.00             0.00
# ...     ...           ...          ...           ...              ...
# 63911    74   El Salvador          SLV       1330.51          1333.48
# 63912    75          Oman          OMA       1320.29          1323.03
# 63913    76        Israel          ISR       1316.55          1316.35
# 63914    78       Georgia          GEO       1307.34          1296.46
# 63915   211    San Marino          SMR        762.22           763.82
#
#        rank_change confederation   rank_date
# 0                0          UEFA  1992-12-31
# 1                0           AFC  1992-12-31
# 2                0           CAF  1992-12-31
# 3                0          UEFA  1992-12-31
# 4                0           CAF  1992-12-31
# ...            ...           ...         ...
# 63911            3      CONCACAF  2022-10-06
# 63912            0           AFC  2022-10-06
# 63913            0          UEFA  2022-10-06
# 63914           -4          UEFA  2022-10-06
# 63915            0          UEFA  2022-10-06
#
# [63916 rows x 8 columns]

# %%
abvr_test = rankings_modif['country_full'].groupby(rankings_modif['country_abrv']).unique().apply(pd.Series)
abvr_test
# Out:
#                         0
# country_abrv
# AFG           Afghanistan
# AIA              Anguilla
# ALB               Albania
# ALG               Algeria
# AND               Andorra
# ...                   ...
# YEM                 Yemen
# YUG            Yugoslavia
# ZAI                 Zaire
# ZAM                Zambia
# ZIM              Zimbabwe
#
# [217 rows x 1 columns]

# %%
# Fixed irregular country_full naming in RANKINGS based on team in COUNTRY_CODE

# %% [markdown]
# ## Inconsistent Data
# ### Same country, different fifa_code

# %%
list_of_codes_in_rankings_not_in_current_fifa = list(set(rankings_modif['country_abrv'].unique()) - set(country_codes['code'].unique()))
list_of_codes_in_rankings_not_in_current_fifa
# Out:
# ['YUG', 'ANT', 'SCG', 'ZAI', 'LIB', 'TCH']

# %%
print(list(set(country_codes['code'].unique()) - set(rankings_modif['country_abrv'].unique()) ))
# Out:
# []

# %%
# We need to see why these abbreviation are extra

# %%
rankings_modif.loc[rankings_modif['country_abrv'].isin(list_of_codes_in_rankings_not_in_current_fifa), 'country_full'].unique()
# Out:
# array(['Yugoslavia', 'Czechoslovakia', 'Zaire', 'Serbia and Montenegro',
#        'Netherlands Antilles', 'Lebanon'], dtype=object)

# %%
# Yugoslavia, Czechoslovakia, Serbia and Montenegro and Netherlands Antilles are historically FIFA

# We can change them and their info to their successor
# Yugoslavia, Serbia and Montenegro -> Serbia
# Czechoslovakia -> Czech Republic
# Netherlands Antilles -> Curacao

# MUST Fixes: 
# Zaire is Democratic Republic of the Congo
# Lebanon appears with two different codes LIB and LBN

# %% [markdown]
# ## Fixing Zaire and Lebanon
# ### Lebanon

# %%
rankings_modif2 = rankings_modif.copy()

# %%
# taking care of lebanon
rankings_lebanon = rankings_modif2.loc[rankings_modif2['country_full']=='Lebanon']
rankings_lebanon['country_abrv'].unique()
# Out:
# array(['LBN', 'LIB'], dtype=object)

# %%
# Change LIB to LBN
rankings_modif2['country_abrv'] = rankings_modif2['country_abrv'].replace('LIB','LBN')

# %%
# Test if we fixed Lebanon abrv
rankings_modif2.loc[rankings_modif2['country_abrv']=='LIB']
# Out:
# Empty DataFrame
# Columns: [rank, country_full, country_abrv, total_points, previous_points, rank_change, confederation, rank_date]
# Index: []

# %% [markdown]
# ### Zaire

# %%
# taking care of Zaire
rankings_zaire = rankings_modif2.loc[rankings_modif2['country_abrv']=='ZAI']
rankings_zaire.iloc[0]
# Out:
# rank                       60
# country_full            Zaire
# country_abrv              ZAI
# total_points             25.0
# previous_points           0.0
# rank_change                 0
# confederation             CAF
# rank_date          1992-12-31
# Name: 117, dtype: object

# %%
rankings_cod = rankings_modif2.loc[rankings_modif2['country_abrv']=='COD']
rankings_cod['country_full'].iloc[0]
# Out:
# 'Congo DR'

# %%
rankings_modif2['country_full'] = rankings_modif2['country_full'].replace(rankings_zaire['country_full'].iloc[0], rankings_cod['country_full'].iloc[0])
rankings_modif2['country_abrv'] = rankings_modif2['country_abrv'].replace(rankings_zaire['country_abrv'].iloc[0], rankings_cod['country_abrv'].iloc[0])

# %%
rankings_modif2.loc[rankings_modif2['country_full']=='Zaire']
# Out:
# Empty DataFrame
# Columns: [rank, country_full, country_abrv, total_points, previous_points, rank_change, confederation, rank_date]
# Index: []

# %%
rankings_modif2
# Out:
#        rank  country_full country_abrv  total_points  previous_points  \
# 0         1       Germany          GER         57.00             0.00
# 1        96         Syria          SYR         11.00             0.00
# 2        97  Burkina Faso          BFA         11.00             0.00
# 3        99        Latvia          LVA         10.00             0.00
# 4       100       Burundi          BDI         10.00             0.00
# ...     ...           ...          ...           ...              ...
# 63911    74   El Salvador          SLV       1330.51          1333.48
# 63912    75          Oman          OMA       1320.29          1323.03
# 63913    76        Israel          ISR       1316.55          1316.35
# 63914    78       Georgia          GEO       1307.34          1296.46
# 63915   211    San Marino          SMR        762.22           763.82
#
#        rank_change confederation   rank_date
# 0                0          UEFA  1992-12-31
# 1                0           AFC  1992-12-31
# 2                0           CAF  1992-12-31
# 3                0          UEFA  1992-12-31
# 4                0           CAF  1992-12-31
# ...            ...           ...         ...
# 63911            3      CONCACAF  2022-10-06
# 63912            0           AFC  2022-10-06
# 63913            0          UEFA  2022-10-06
# 63914           -4          UEFA  2022-10-06
# 63915            0          UEFA  2022-10-06
#
# [63916 rows x 8 columns]

# %%
# Codes check
codes_in_rankings_not_in_fifa = list(set(rankings_modif2['country_abrv'].unique()) - set(country_codes['code'].unique()))
print(codes_in_rankings_not_in_fifa,rankings_modif2.loc[rankings_modif2['country_abrv'].isin(codes_in_rankings_not_in_fifa), 'country_full'].unique())
# Out:
# ['YUG', 'ANT', 'TCH', 'SCG'] ['Yugoslavia' 'Czechoslovakia' 'Serbia and Montenegro'
#  'Netherlands Antilles']

# %% [markdown]
# ## These are all former FIFA countries
# ### Let's explore each and see how we can fix them

# %% [markdown]
# ## Czechoslovakia -> Czech Republic

# %%
rankings_modif2.loc[rankings_modif2['country_full']=='Czechoslovakia']
# Out:
#      rank    country_full country_abrv  total_points  previous_points  \
# 93     18  Czechoslovakia          TCH          47.0              0.0
# 257    15  Czechoslovakia          TCH          50.0             47.0
# 396    17  Czechoslovakia          TCH          50.0             50.0
# 454    21  Czechoslovakia          TCH          47.0             50.0
# 714    19  Czechoslovakia          TCH          50.0             47.0
# 833    19  Czechoslovakia          TCH          49.0             50.0
#
#      rank_change confederation   rank_date
# 93             0          UEFA  1992-12-31
# 257           -3          UEFA  1993-08-08
# 396            2          UEFA  1993-09-23
# 454            4          UEFA  1993-10-22
# 714           -2          UEFA  1993-11-19
# 833            0          UEFA  1993-12-23

# %%
rankings_modif2.loc[rankings_modif2['country_full']=='Czech Republic']
# Out:
#        rank    country_full country_abrv  total_points  previous_points  \
# 1144     67  Czech Republic          CZE         24.00             0.00
# 1255     63  Czech Republic          CZE         28.00            24.00
# 1372     59  Czech Republic          CZE         28.00            28.00
# 1560     45  Czech Republic          CZE         35.00            28.00
# 1814     44  Czech Republic          CZE         35.00            35.00
# ...     ...             ...          ...           ...              ...
# 62959    31  Czech Republic          CZE       1510.42          1510.42
# 63181    33  Czech Republic          CZE       1500.62          1510.42
# 63383    32  Czech Republic          CZE       1502.90          1500.62
# 63604    32  Czech Republic          CZE       1502.90          1502.90
# 63818    35  Czech Republic          CZE       1492.21          1502.90
#
#        rank_change confederation   rank_date
# 1144             0          UEFA  1994-03-15
# 1255            -4          UEFA  1994-04-19
# 1372            -4          UEFA  1994-05-17
# 1560           -14          UEFA  1994-06-14
# 1814            -1          UEFA  1994-07-21
# ...            ...           ...         ...
# 62959           -1          UEFA  2022-02-10
# 63181            2          UEFA  2022-03-31
# 63383           -1          UEFA  2022-06-23
# 63604            0          UEFA  2022-08-25
# 63818            3          UEFA  2022-10-06
#
# [315 rows x 8 columns]

# %%
rankings_modif2.loc[rankings_modif2['country_full']=='Slovakia']
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 651     146     Slovakia          SVK          2.00             0.00
# 761     150     Slovakia          SVK          2.00             2.00
# 1022     58     Slovakia          SVK         30.00             2.00
# 1186     60     Slovakia          SVK         30.00            30.00
# 1246     54     Slovakia          SVK         32.00            30.00
# ...     ...          ...          ...           ...              ...
# 62944    46     Slovakia          SVK       1455.36          1455.36
# 63193    45     Slovakia          SVK       1454.98          1455.36
# 63364    51     Slovakia          SVK       1439.99          1454.98
# 63623    51     Slovakia          SVK       1439.99          1439.99
# 63892    55     Slovakia          SVK       1425.59          1439.99
#
#        rank_change confederation   rank_date
# 651              0          UEFA  1993-11-19
# 761              4          UEFA  1993-12-23
# 1022           -92          UEFA  1994-02-15
# 1186             2          UEFA  1994-03-15
# 1246            -6          UEFA  1994-04-19
# ...            ...           ...         ...
# 62944            4          UEFA  2022-02-10
# 63193           -1          UEFA  2022-03-31
# 63364            6          UEFA  2022-06-23
# 63623            0          UEFA  2022-08-25
# 63892            4          UEFA  2022-10-06
#
# [318 rows x 8 columns]

# %% [markdown]
# ### After analyzing these, it seems that we can simply eliminate Czechoslovakia rankings from the database

# %%
rankings_modif2 = rankings_modif2[rankings_modif2['country_full'] != 'Czechoslovakia']

# %%
# See what codes remain codes
codes_in_rankings_not_in_fifa = list(set(rankings_modif2['country_abrv'].unique()) - set(country_codes['code'].unique()))
countries_in_rankings_not_in_fifa = rankings_modif2.loc[rankings_modif['country_abrv'].isin(codes_in_rankings_not_in_fifa), 'country_full'].unique()

print(codes_in_rankings_not_in_fifa, countries_in_rankings_not_in_fifa)
# Out:
# ['YUG', 'ANT', 'SCG'] ['Yugoslavia' 'Serbia and Montenegro' 'Netherlands Antilles']

# %% [markdown]
# ## Yugoslavia -> Serbia and Montenegro -> Serbia
# ### Since FIFA decided to inherit the points like this, we change the country names
# #### We will only represent current fifa countries, anyways

# %%
rankings_modif2.loc[rankings_modif2['country_full']=='Yugoslavia']
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 84       29   Yugoslavia          YUG          39.0              0.0
# 279      56   Yugoslavia          YUG          31.0             39.0
# 418      62   Yugoslavia          YUG          30.0             31.0
# 583      65   Yugoslavia          YUG          29.0             30.0
# 732      67   Yugoslavia          YUG          28.0             29.0
# ...     ...          ...          ...           ...              ...
# 18135    16   Yugoslavia          YUG         689.0            702.0
# 18179    16   Yugoslavia          YUG         688.0            689.0
# 18488    20   Yugoslavia          YUG         672.0            688.0
# 18655    16   Yugoslavia          YUG         690.0            672.0
# 18933    16   Yugoslavia          YUG         687.0            690.0
#
#        rank_change confederation   rank_date
# 84               0          UEFA  1992-12-31
# 279             27          UEFA  1993-08-08
# 418              6          UEFA  1993-09-23
# 583              3          UEFA  1993-10-22
# 732              2          UEFA  1993-11-19
# ...            ...           ...         ...
# 18135            6          UEFA  2002-07-03
# 18179            0          UEFA  2002-08-14
# 18488            4          UEFA  2002-09-18
# 18655           -4          UEFA  2002-10-23
# 18933            0          UEFA  2002-11-20
#
# [102 rows x 8 columns]

# %%
rankings_modif2.loc[rankings_modif2['country_full']=='Serbia and Montenegro']
# Out:
#        rank           country_full country_abrv  total_points  \
# 19127    19  Serbia and Montenegro          SCG         678.0
# 19196    19  Serbia and Montenegro          SCG         677.0
# 19571    19  Serbia and Montenegro          SCG         674.0
# 19650    20  Serbia and Montenegro          SCG         667.0
# 19972    22  Serbia and Montenegro          SCG         659.0
# 20065    22  Serbia and Montenegro          SCG         650.0
# 20326    27  Serbia and Montenegro          SCG         636.0
# 20578    33  Serbia and Montenegro          SCG         621.0
# 20714    29  Serbia and Montenegro          SCG         621.0
# 20890    35  Serbia and Montenegro          SCG         622.0
# 21099    32  Serbia and Montenegro          SCG         627.0
# 21251    36  Serbia and Montenegro          SCG         618.0
# 21511    41  Serbia and Montenegro          SCG         605.0
# 21636    41  Serbia and Montenegro          SCG         605.0
# 21939    43  Serbia and Montenegro          SCG         602.0
# 22105    43  Serbia and Montenegro          SCG         597.0
# 22299    44  Serbia and Montenegro          SCG         591.0
# 22575    45  Serbia and Montenegro          SCG         583.0
# 22825    44  Serbia and Montenegro          SCG         581.0
# 22918    48  Serbia and Montenegro          SCG         574.0
# 23123    44  Serbia and Montenegro          SCG         583.0
# 23397    51  Serbia and Montenegro          SCG         566.0
# 23528    55  Serbia and Montenegro          SCG         570.0
# 23659    54  Serbia and Montenegro          SCG         577.0
# 24043    46  Serbia and Montenegro          SCG         599.0
# 24177    46  Serbia and Montenegro          SCG         599.0
# 24343    46  Serbia and Montenegro          SCG         597.0
# 24549    46  Serbia and Montenegro          SCG         595.0
# 24802    47  Serbia and Montenegro          SCG         600.0
# 24920    46  Serbia and Montenegro          SCG         601.0
# 25197    49  Serbia and Montenegro          SCG         598.0
# 25387    49  Serbia and Montenegro          SCG         595.0
# 25549    49  Serbia and Montenegro          SCG         593.0
# 25832    48  Serbia and Montenegro          SCG         601.0
# 26015    42  Serbia and Montenegro          SCG         623.0
# 26215    47  Serbia and Montenegro          SCG         612.0
# 26434    47  Serbia and Montenegro          SCG         612.0
# 26627    47  Serbia and Montenegro          SCG         612.0
# 26735    47  Serbia and Montenegro          SCG         611.0
# 26985    46  Serbia and Montenegro          SCG         616.0
# 27243    46  Serbia and Montenegro          SCG         612.0
# 27443    44  Serbia and Montenegro          SCG         610.0
# 27613    36  Serbia and Montenegro          SCG         724.0
#
#        previous_points  rank_change confederation   rank_date
# 19127              0.0            0          UEFA  2002-12-18
# 19196            678.0            0          UEFA  2003-01-15
# 19571            677.0            0          UEFA  2003-02-19
# 19650            674.0            1          UEFA  2003-03-26
# 19972            667.0            2          UEFA  2003-04-23
# 20065            659.0            0          UEFA  2003-05-21
# 20326            650.0            5          UEFA  2003-06-25
# 20578            636.0            6          UEFA  2003-07-30
# 20714            621.0           -4          UEFA  2003-08-27
# 20890            621.0            6          UEFA  2003-09-24
# 21099            622.0           -3          UEFA  2003-10-22
# 21251            627.0            4          UEFA  2003-11-19
# 21511            618.0            5          UEFA  2003-12-15
# 21636            605.0            0          UEFA  2004-01-14
# 21939            605.0            2          UEFA  2004-02-18
# 22105            602.0            0          UEFA  2004-03-17
# 22299            597.0            1          UEFA  2004-04-14
# 22575            591.0            1          UEFA  2004-05-12
# 22825            583.0           -1          UEFA  2004-06-09
# 22918            581.0            4          UEFA  2004-07-07
# 23123            574.0           -4          UEFA  2004-08-04
# 23397            583.0            7          UEFA  2004-09-01
# 23528            566.0            4          UEFA  2004-10-06
# 23659            570.0           -1          UEFA  2004-11-10
# 24043            577.0           -8          UEFA  2004-12-20
# 24177            599.0            0          UEFA  2005-01-19
# 24343            599.0            0          UEFA  2005-02-16
# 24549            597.0            0          UEFA  2005-03-23
# 24802            595.0            1          UEFA  2005-04-20
# 24920            600.0           -1          UEFA  2005-05-18
# 25197            601.0            3          UEFA  2005-06-15
# 25387            598.0            0          UEFA  2005-07-20
# 25549            595.0            0          UEFA  2005-08-17
# 25832            593.0           -1          UEFA  2005-09-12
# 26015            601.0           -6          UEFA  2005-10-17
# 26215            623.0            5          UEFA  2005-11-21
# 26434            612.0            0          UEFA  2005-12-16
# 26627            612.0            0          UEFA  2006-01-18
# 26735            612.0            0          UEFA  2006-02-15
# 26985            611.0           -1          UEFA  2006-03-15
# 27243            616.0            0          UEFA  2006-04-19
# 27443            612.0           -2          UEFA  2006-05-17
# 27613            610.0           -8          UEFA  2006-07-12

# %%
rankings_modif2.loc[rankings_modif2['country_full']=='Serbia']
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 26460    47       Serbia          SRB        612.00             0.00
# 27614    36       Serbia          SRB        724.00             0.00
# 27831    33       Serbia          SRB        733.00           724.00
# 28024    32       Serbia          SRB        759.00           733.00
# 28220    32       Serbia          SRB        767.00           759.00
# ...     ...          ...          ...           ...              ...
# 62964    25       Serbia          SRB       1547.38          1547.38
# 63226    25       Serbia          SRB       1547.53          1547.38
# 63337    25       Serbia          SRB       1549.53          1547.53
# 63650    25       Serbia          SRB       1549.53          1549.53
# 63857    21       Serbia          SRB       1563.62          1549.53
#
#        rank_change confederation   rank_date
# 26460            0          UEFA  2005-12-16
# 27614            0          UEFA  2006-07-12
# 27831           -3          UEFA  2006-08-16
# 28024           -1          UEFA  2006-09-13
# 28220            0          UEFA  2006-10-18
# ...            ...           ...         ...
# 62964            2          UEFA  2022-02-10
# 63226            0          UEFA  2022-03-31
# 63337            0          UEFA  2022-06-23
# 63650            0          UEFA  2022-08-25
# 63857           -4          UEFA  2022-10-06
#
# [179 rows x 8 columns]

# %% [markdown]
# ### Change Yugoslavia, Serbia and Montenegro to Serbia
# ### Change YUG, SCG to SRB

# %% [markdown]
# ## Netherlands Antilles - Curacao

# %%
# Netherlands Antilles 
rankings_modif2.loc[rankings_modif2['country_abrv']=='ANT']
# Out:
#        rank          country_full country_abrv  total_points  previous_points  \
# 29765   173  Netherlands Antilles          ANT          43.0             47.0
# 29957   174  Netherlands Antilles          ANT          41.0             43.0
# 30137   177  Netherlands Antilles          ANT          41.0             41.0
# 30405   182  Netherlands Antilles          ANT          30.0             41.0
# 30520   183  Netherlands Antilles          ANT          30.0             30.0
# 30750   183  Netherlands Antilles          ANT          30.0             30.0
# 31026   183  Netherlands Antilles          ANT          30.0             30.0
# 31234   179  Netherlands Antilles          ANT          32.0             30.0
# 31321   161  Netherlands Antilles          ANT          93.0             32.0
# 31631   163  Netherlands Antilles          ANT          93.0             93.0
# 31856   150  Netherlands Antilles          ANT         143.0             93.0
# 32083   153  Netherlands Antilles          ANT         138.0            143.0
# 32189   146  Netherlands Antilles          ANT         167.0            138.0
# 32336   149  Netherlands Antilles          ANT         171.0            167.0
# 32588   147  Netherlands Antilles          ANT         173.0            171.0
# 32704   147  Netherlands Antilles          ANT         173.0            173.0
# 32914   151  Netherlands Antilles          ANT         169.0            173.0
# 33203   155  Netherlands Antilles          ANT         128.0            169.0
# 33378   152  Netherlands Antilles          ANT         128.0            128.0
# 33501   154  Netherlands Antilles          ANT         128.0            128.0
# 33731   152  Netherlands Antilles          ANT         142.0            128.0
# 33919   153  Netherlands Antilles          ANT         142.0            142.0
# 34122   149  Netherlands Antilles          ANT         152.0            142.0
# 34306   147  Netherlands Antilles          ANT         152.0            152.0
# 34623   145  Netherlands Antilles          ANT         160.0            152.0
# 34813   140  Netherlands Antilles          ANT         169.0            160.0
# 34983   165  Netherlands Antilles          ANT          88.0            169.0
# 35267   164  Netherlands Antilles          ANT          88.0             88.0
# 35481   164  Netherlands Antilles          ANT          85.0             88.0
# 35597   168  Netherlands Antilles          ANT          80.0             85.0
# 35822   168  Netherlands Antilles          ANT          80.0             80.0
# 35999   169  Netherlands Antilles          ANT          80.0             80.0
# 36203   166  Netherlands Antilles          ANT          90.0             80.0
# 36353   162  Netherlands Antilles          ANT          98.0             90.0
# 36690   157  Netherlands Antilles          ANT          98.0             98.0
# 36779   154  Netherlands Antilles          ANT         103.0             98.0
# 37083   150  Netherlands Antilles          ANT         108.0            103.0
# 37160   165  Netherlands Antilles          ANT          67.0            108.0
# 37420   166  Netherlands Antilles          ANT          63.0             67.0
# 37601   170  Netherlands Antilles          ANT          63.0             63.0
# 37773   153  Netherlands Antilles          ANT         107.0             63.0
# 37976   151  Netherlands Antilles          ANT         107.0            107.0
# 38198   150  Netherlands Antilles          ANT         107.0            107.0
# 38339   150  Netherlands Antilles          ANT         107.0            107.0
#
#        rank_change confederation   rank_date
# 29765           -1      CONCACAF  2007-06-13
# 29957            1      CONCACAF  2007-07-18
# 30137            3      CONCACAF  2007-08-22
# 30405            5      CONCACAF  2007-09-19
# 30520            1      CONCACAF  2007-10-24
# 30750            0      CONCACAF  2007-11-22
# 31026            0      CONCACAF  2007-12-17
# 31234           -4      CONCACAF  2008-01-16
# 31321          -18      CONCACAF  2008-02-13
# 31631            2      CONCACAF  2008-03-12
# 31856          -13      CONCACAF  2008-04-09
# 32083            3      CONCACAF  2008-05-07
# 32189           -7      CONCACAF  2008-06-04
# 32336            3      CONCACAF  2008-07-02
# 32588           -2      CONCACAF  2008-08-06
# 32704            0      CONCACAF  2008-09-03
# 32914            4      CONCACAF  2008-10-08
# 33203            4      CONCACAF  2008-11-12
# 33378           -3      CONCACAF  2008-12-17
# 33501            2      CONCACAF  2009-01-14
# 33731           -2      CONCACAF  2009-02-11
# 33919            1      CONCACAF  2009-03-11
# 34122           -4      CONCACAF  2009-04-08
# 34306           -2      CONCACAF  2009-05-06
# 34623           -2      CONCACAF  2009-06-03
# 34813           -5      CONCACAF  2009-07-01
# 34983           25      CONCACAF  2009-08-05
# 35267           -1      CONCACAF  2009-09-02
# 35481            0      CONCACAF  2009-10-16
# 35597            4      CONCACAF  2009-11-20
# 35822            0      CONCACAF  2009-12-16
# 35999            1      CONCACAF  2010-02-03
# 36203           -3      CONCACAF  2010-03-03
# 36353           -4      CONCACAF  2010-03-31
# 36690           -5      CONCACAF  2010-04-28
# 36779           -3      CONCACAF  2010-05-26
# 37083           -4      CONCACAF  2010-07-14
# 37160           15      CONCACAF  2010-08-11
# 37420            1      CONCACAF  2010-09-15
# 37601            4      CONCACAF  2010-10-20
# 37773          -17      CONCACAF  2010-11-17
# 37976           -2      CONCACAF  2010-12-15
# 38198           -1      CONCACAF  2011-01-12
# 38339            0      CONCACAF  2011-02-02

# %%
# Netherlands Antilles -> Curacao
rankings_modif2.loc[rankings_modif2['country_abrv']=='CUW']
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 38197   150      Curaçao          CUW        107.00           109.00
# 38340   150      Curaçao          CUW        107.00           107.00
# 38592   146      Curaçao          CUW        115.00           107.00
# 38732   152      Curaçao          CUW        121.00           115.00
# 39003   152      Curaçao          CUW        121.00           121.00
# ...     ...          ...          ...           ...              ...
# 62910    80      Curaçao          CUW       1298.39          1298.39
# 63280    79      Curaçao          CUW       1298.39          1298.39
# 63331    84      Curaçao          CUW       1293.35          1298.39
# 63657    84      Curaçao          CUW       1293.35          1293.35
# 63869    86      Curaçao          CUW       1278.64          1293.35
#
#        rank_change confederation   rank_date
# 38197            1      CONCACAF  2011-01-12
# 38340            0      CONCACAF  2011-02-02
# 38592           -4      CONCACAF  2011-03-09
# 38732            6      CONCACAF  2011-04-13
# 39003            0      CONCACAF  2011-05-18
# ...            ...           ...         ...
# 62910            0      CONCACAF  2022-02-10
# 63280           -1      CONCACAF  2022-03-31
# 63331            5      CONCACAF  2022-06-23
# 63657            0      CONCACAF  2022-08-25
# 63869            2      CONCACAF  2022-10-06
#
# [125 rows x 8 columns]

# %% [markdown]
# ### Change Netherlands Antilles to Curaçao
# ### Change ANT to CUW

# %%
print(codes_in_rankings_not_in_fifa, countries_in_rankings_not_in_fifa)
# Out:
# ['YUG', 'ANT', 'SCG'] ['Yugoslavia' 'Serbia and Montenegro' 'Netherlands Antilles']

# %%
list_of_codes_changed = ['SRB','CUW','SRB']
list_of_countries_changed = ['Serbia','Serbia','Curaçao']

# %%
rankings_modif2['country_full'] = rankings_modif2['country_full'].replace(countries_in_rankings_not_in_fifa, list_of_countries_changed)
rankings_modif2['country_abrv'] = rankings_modif2['country_abrv'].replace(codes_in_rankings_not_in_fifa, list_of_codes_changed)
# Out:
# C:\Users\gabipana\AppData\Local\Temp\ipykernel_8696\42676831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rankings_modif2['country_full'] = rankings_modif2['country_full'].replace(countries_in_rankings_not_in_fifa, list_of_countries_changed)
# C:\Users\gabipana\AppData\Local\Temp\ipykernel_8696\42676831.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rankings_modif2['country_abrv'] = rankings_modif2['country_abrv'].replace(codes_in_rankings_not_in_fifa, list_of_codes_changed)

# %%
# Test
# See what codes remain codes
test_abrv = list(set(rankings_modif2['country_abrv'].unique()) - set(country_codes['code'].unique()))
test_countries = rankings_modif2.loc[rankings_modif['country_abrv'].isin(test_abrv), 'country_full'].unique()

print(test_abrv, test_countries)
# Out:
# [] []

# %%
rankings_modif2.to_csv('./data/fifa_rankings.csv', index=False)

# %% [markdown]
# ## Duplicates

# %% [markdown]
# ### Check duplicate rows based on country and date of evaluation

# %%
duplicates = rankings_modif2[rankings_modif2.duplicated(subset=['country_full','rank_date'], keep=False)]
duplicates
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 26434    47       Serbia          SRB         612.0            612.0
# 26460    47       Serbia          SRB         612.0              0.0
# 27613    36       Serbia          SRB         724.0            610.0
# 27614    36       Serbia          SRB         724.0              0.0
# 30386   186   Montenegro          MNE          21.0              0.0
# 30407   186   Montenegro          MNE          21.0              0.0
# 30580   171   Montenegro          MNE          65.0             21.0
# 30660   171   Montenegro          MNE          65.0             21.0
# 30783   172   Montenegro          MNE          65.0             65.0
# 30784   172   Montenegro          MNE          65.0             65.0
# 30987   172   Montenegro          MNE          65.0             65.0
# 30988   172   Montenegro          MNE          65.0             65.0
# 31203   172   Montenegro          MNE          65.0             65.0
# 31204   172   Montenegro          MNE          65.0             65.0
# 31354   175   Montenegro          MNE          65.0             65.0
# 31355   175   Montenegro          MNE          65.0             65.0
# 31664   175   Montenegro          MNE          65.0             65.0
# 31679   175   Montenegro          MNE          65.0             65.0
# 38197   150      Curaçao          CUW         107.0            109.0
# 38198   150      Curaçao          CUW         107.0            107.0
# 38339   150      Curaçao          CUW         107.0            107.0
# 38340   150      Curaçao          CUW         107.0            107.0
#
#        rank_change confederation   rank_date
# 26434            0          UEFA  2005-12-16
# 26460            0          UEFA  2005-12-16
# 27613           -8          UEFA  2006-07-12
# 27614            0          UEFA  2006-07-12
# 30386          -13          UEFA  2007-09-19
# 30407          -13          UEFA  2007-09-19
# 30580          -15          UEFA  2007-10-24
# 30660          -15          UEFA  2007-10-24
# 30783            1          UEFA  2007-11-22
# 30784            1          UEFA  2007-11-22
# 30987            0          UEFA  2007-12-17
# 30988            0          UEFA  2007-12-17
# 31203            0          UEFA  2008-01-16
# 31204            0          UEFA  2008-01-16
# 31354            3          UEFA  2008-02-13
# 31355            3          UEFA  2008-02-13
# 31664            0          UEFA  2008-03-12
# 31679            0          UEFA  2008-03-12
# 38197            1      CONCACAF  2011-01-12
# 38198           -1      CONCACAF  2011-01-12
# 38339            0      CONCACAF  2011-02-02
# 38340            0      CONCACAF  2011-02-02

# %% [markdown]
# ## Standardizing the country_full names to the team from country_codes table
