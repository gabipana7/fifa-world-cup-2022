# %%
import pandas as pd

# %%
country_codes = pd.read_csv('./data/country_codes.csv')
rankings = pd.read_csv('./data/fifa_rankings.csv')
matches = pd.read_csv('./data/matches.csv')

# %%
matches
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 0             1  1872-11-30       Scotland       England         0.0
# 1             2  1873-03-08        England      Scotland         4.0
# 2             3  1874-03-07       Scotland       England         2.0
# 3             4  1875-03-06        England      Scotland         2.0
# 4             5  1876-03-04       Scotland       England         3.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament       city   country  neutral
# 0             0.0        Friendly    Glasgow  Scotland    False
# 1             2.0        Friendly     London   England    False
# 2             1.0        Friendly    Glasgow  Scotland    False
# 3             2.0        Friendly     London   England    False
# 4             0.0        Friendly    Glasgow  Scotland    False
# ...           ...             ...        ...       ...      ...
# 44159         2.0  FIFA World Cup       Doha     Qatar     True
# 44160         2.0  FIFA World Cup  Al Rayyan     Qatar     True
# 44161         1.0  FIFA World Cup  Al Rayyan     Qatar     True
# 44162         2.0  FIFA World Cup     Lusail     Qatar     True
# 44163         0.0  FIFA World Cup  Al Rayyan     Qatar     True
#
# [44164 rows x 10 columns]

# %%
rankings['rank_date'].iloc[0]
# Out:
# '1992-12-31'

# %%
matches_trimmed = matches.copy()

# %%
# Trim matches
matches_trimmed.drop(matches_trimmed[matches_trimmed['date'] <= rankings['rank_date'].iloc[0]].index, inplace = True)
matches_trimmed
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 17697     17698  1993-01-01          Ghana          Mali         1.0
# 17698     17699  1993-01-02          Gabon  Burkina Faso         1.0
# 17699     17700  1993-01-02         Kuwait       Lebanon         2.0
# 17700     17701  1993-01-03   Burkina Faso          Mali         1.0
# 17701     17702  1993-01-03          Gabon         Ghana         2.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament         city country  neutral
# 17697         1.0        Friendly   Libreville   Gabon     True
# 17698         1.0        Friendly   Libreville   Gabon    False
# 17699         0.0        Friendly  Kuwait City  Kuwait    False
# 17700         0.0        Friendly   Libreville   Gabon     True
# 17701         3.0        Friendly   Libreville   Gabon    False
# ...           ...             ...          ...     ...      ...
# 44159         2.0  FIFA World Cup         Doha   Qatar     True
# 44160         2.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44161         1.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44162         2.0  FIFA World Cup       Lusail   Qatar     True
# 44163         0.0  FIFA World Cup    Al Rayyan   Qatar     True
#
# [26467 rows x 10 columns]

# %%
# Countries in Rankings but NOT in Matches


# first see which countries are in rankings but not in matches
countries_in_rankings_not_in_matches = list(set(rankings['country_full'].unique()) - set(matches_trimmed['home_team'].unique()))

# Create series with all countries in matches and the number of matches
countries_list_matches = rankings['country_full'].value_counts()

# Then filter the  list of matches using the countries that are in matches but not in federation
print((countries_list_matches.loc[countries_in_rankings_not_in_matches]).sort_values(ascending=False))

# This way we see how we should reformat the countries from confederations
# Out:
# IR Iran                  322
# Korea Republic           322
# Korea DPR                322
# Côte d'Ivoire            322
# Congo DR                 322
# St. Lucia                322
# Brunei Darussalam        322
# USA                      322
# Kyrgyz Republic          307
# St. Kitts and Nevis      305
# Chinese Taipei           291
# US Virgin Islands        243
# Yugoslavia               102
# Netherlands Antilles      44
# Serbia and Montenegro     43
# Czechoslovakia             6
# Name: country_full, dtype: int64

# %%
print(list(set(matches_trimmed['home_team'].unique()) - set(rankings['country_full'].unique())))
# Out:
# ['Iran', 'Padania', 'Parishes of Jersey', 'Felvidék', 'Kyrgyzstan', 'Yoruba Nation', 'Ellan Vannin', 'Palau', 'Isle of Man', 'Orkney', 'Provence', 'County of Nice', 'Basque Country', 'Barawa', 'Silesia', 'French Guiana', 'Western Sahara', 'Raetia', 'Tuvalu', 'Saint Helena', 'Kiribati', 'Frøya', 'Darfur', 'Western Armenia', 'Micronesia', 'North Korea', 'United States Virgin Islands', 'Falkland Islands', 'Aymara', 'Occitania', 'Northern Mariana Islands', 'Saare County', 'South Korea', 'Saint Kitts and Nevis', 'Monaco', 'Saint Pierre and Miquelon', 'Matabeleland', 'Iraqi Kurdistan', 'Sark', 'Arameans Suryoye', 'Saint Lucia', 'Brunei', 'Somaliland', 'Sint Maarten', 'Hitra', 'Gotland', 'Catalonia', 'Saint Martin', 'Alderney', 'Vatican City', 'Găgăuzia', 'Yorkshire', 'Corsica', 'Jersey', 'Abkhazia', 'Guadeloupe', 'United Koreans in Japan', 'Sápmi', 'Zanzibar', 'Artsakh', 'Isle of Wight', 'Bonaire', 'Guernsey', 'Székely Land', 'DR Congo', 'Andalusia', 'Romani people', 'Ynys Môn', 'Kernow', 'Rhodes', 'Kárpátalja', 'Mapuche', 'Brittany', 'Greenland', 'Panjab', 'Canary Islands', 'Western Isles', 'Menorca', 'Gozo', 'Martinique', 'Republic of St. Pauli', 'Galicia', 'Åland Islands', 'Madrid', 'Chagos Islands', 'United States', 'Kabylia', 'Chameria', 'Ivory Coast', 'South Ossetia', 'Mayotte', 'Taiwan', 'Shetland', 'Cascadia', 'Biafra', 'Tamil Eelam', 'Tibet', 'Northern Cyprus', 'Réunion']

# %%
print(list(set(matches_trimmed['home_team'].unique()) - set(country_codes['team'].unique())))
# Out:
# ['Padania', 'Parishes of Jersey', 'Felvidék', 'Yoruba Nation', 'Ellan Vannin', 'Palau', 'Isle of Man', 'Orkney', 'Provence', 'County of Nice', 'Basque Country', 'Barawa', 'Silesia', 'French Guiana', 'Western Sahara', 'Raetia', 'Tuvalu', 'Saint Helena', 'Kiribati', 'Frøya', 'Darfur', 'Western Armenia', 'Micronesia', 'United States Virgin Islands', 'Falkland Islands', 'Aymara', 'Occitania', 'Northern Mariana Islands', 'Saare County', 'Monaco', 'Saint Pierre and Miquelon', 'Matabeleland', 'Iraqi Kurdistan', 'Sark', 'Arameans Suryoye', 'Somaliland', 'Sint Maarten', 'Hitra', 'Gotland', 'Catalonia', 'Saint Martin', 'Alderney', 'Vatican City', 'Găgăuzia', 'Yorkshire', 'Corsica', 'Jersey', 'Abkhazia', 'Guadeloupe', 'United Koreans in Japan', 'Sápmi', 'Zanzibar', 'Artsakh', 'Isle of Wight', 'Bonaire', 'Guernsey', 'Székely Land', 'China PR', 'Andalusia', 'Romani people', 'Ynys Môn', 'Kernow', 'Rhodes', 'Kárpátalja', 'Mapuche', 'Brittany', 'Greenland', 'Panjab', 'Canary Islands', 'Western Isles', 'Menorca', 'Gozo', 'Martinique', 'Republic of St. Pauli', 'Galicia', 'Åland Islands', 'Madrid', 'Chagos Islands', 'Kabylia', 'Chameria', 'South Ossetia', 'Mayotte', 'Taiwan', 'Shetland', 'Cascadia', 'Biafra', 'Tamil Eelam', 'Tibet', 'Northern Cyprus', 'Réunion']

# %%
len(list(set(matches_trimmed['home_team'].unique()) - set(country_codes['team'].unique())))
# Out:
# 90

# %%
# Countries IN Matches but NOT IN Rankings


# first see which countries are in matches but not in rankings
countries_in_matches_not_in_rankings = list(set(matches_trimmed['home_team'].unique()) - set(rankings['country_full'].unique()))

# Create series with all countries in matches and the number of matches
countries_list = matches_trimmed['home_team'].value_counts()

# Then filter the list of matches using the countries that are in matches but not in rankings (first 25 with most matches)
print((countries_list.loc[countries_in_matches_not_in_rankings]).sort_values(ascending=False).head(25))
# Out:
# United States                   339
# South Korea                     269
# Iran                            202
# Ivory Coast                     162
# DR Congo                        127
# Saint Kitts and Nevis            93
# Martinique                       91
# North Korea                      80
# Guadeloupe                       71
# Saint Lucia                      63
# Kyrgyzstan                       63
# French Guiana                    48
# Jersey                           46
# Guernsey                         37
# Padania                          28
# Zanzibar                         28
# United States Virgin Islands     26
# Greenland                        26
# Ynys Môn                         25
# Basque Country                   24
# Isle of Wight                    24
# Catalonia                        23
# Taiwan                           22
# Isle of Man                      22
# Brunei                           21
# Name: home_team, dtype: int64

# %%
rankings.loc[rankings['country_full']=='IR Iran']
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 118      61      IR Iran          IRN         24.00             0.00
# 296      54      IR Iran          IRN         32.00            24.00
# 433      58      IR Iran          IRN         31.00            32.00
# 567      59      IR Iran          IRN         30.00            31.00
# 733      58      IR Iran          IRN         31.00            30.00
# ...     ...          ...          ...           ...              ...
# 62915    21      IR Iran          IRN       1572.89          1557.58
# 63222    21      IR Iran          IRN       1564.49          1572.89
# 63339    23      IR Iran          IRN       1558.64          1564.49
# 63647    22      IR Iran          IRN       1558.64          1558.64
# 63856    20      IR Iran          IRN       1564.61          1558.64
#
#        rank_change confederation   rank_date
# 118              0           AFC  1992-12-31
# 296             -7           AFC  1993-08-08
# 433              4           AFC  1993-09-23
# 567              1           AFC  1993-10-22
# 733             -1           AFC  1993-11-19
# ...            ...           ...         ...
# 62915            0           AFC  2022-02-10
# 63222            0           AFC  2022-03-31
# 63339            2           AFC  2022-06-23
# 63647           -1           AFC  2022-08-25
# 63856           -2           AFC  2022-10-06
#
# [322 rows x 8 columns]

# %%
matches_trimmed.loc[matches_trimmed['home_team']=='Curaçao']
# Out:
#        match_id        date home_team                         away_team  \
# 19211     19212  1995-05-14   Curaçao                             Aruba
# 19225     19226  1995-05-25   Curaçao                       Puerto Rico
# 19768     19769  1996-03-23   Curaçao                           Grenada
# 19857     19858  1996-05-11   Curaçao                Dominican Republic
# 21470     21471  1998-03-07   Curaçao                     French Guiana
# ...         ...         ...       ...                               ...
# 42282     42283  2021-03-25   Curaçao  Saint Vincent and the Grenadines
# 42570     42571  2021-06-08   Curaçao                         Guatemala
# 42644     42645  2021-06-15   Curaçao                            Panama
# 43043     43044  2021-10-09   Curaçao                       New Zealand
# 43667     43668  2022-06-03   Curaçao                          Honduras
#
#        home_score  away_score                       tournament           city  \
# 19211         3.0         2.0  CFU Caribbean Cup qualification     Willemstad
# 19225         2.0         2.0  CFU Caribbean Cup qualification  Santo Domingo
# 19768         0.0         1.0  CFU Caribbean Cup qualification     Willemstad
# 19857         0.0         0.0     FIFA World Cup qualification     Willemstad
# 21470         2.0         1.0  CFU Caribbean Cup qualification     Oranjestad
# ...           ...         ...                              ...            ...
# 42282         5.0         0.0     FIFA World Cup qualification     Willemstad
# 42570         0.0         0.0     FIFA World Cup qualification     Willemstad
# 42644         0.0         0.0     FIFA World Cup qualification     Willemstad
# 43043         1.0         2.0                         Friendly          Riffa
# 43667         0.0         1.0          CONCACAF Nations League     Willemstad
#
#                     country  neutral
# 19211  Netherlands Antilles     True
# 19225    Dominican Republic     True
# 19768  Netherlands Antilles     True
# 19857  Netherlands Antilles     True
# 21470                 Aruba     True
# ...                     ...      ...
# 42282               Curaçao    False
# 42570               Curaçao    False
# 42644               Curaçao    False
# 43043               Bahrain     True
# 43667               Curaçao    False
#
# [67 rows x 10 columns]

# %%
matches.loc[matches['home_team']=='Serbia']
# Out:
#        match_id        date home_team      away_team  home_score  away_score  \
# 19130     19131  1995-03-31    Serbia        Uruguay         1.0         0.0
# 19238     19239  1995-05-31    Serbia         Russia         1.0         2.0
# 19790     19791  1996-03-27    Serbia        Romania         1.0         0.0
# 19830     19831  1996-04-24    Serbia  Faroe Islands         3.0         1.0
# 19948     19949  1996-06-02    Serbia          Malta         6.0         0.0
# ...         ...         ...       ...            ...         ...         ...
# 43094     43095  2021-10-12    Serbia     Azerbaijan         3.0         1.0
# 43138     43139  2021-11-11    Serbia          Qatar         4.0         0.0
# 43651     43652  2022-06-02    Serbia         Norway         0.0         1.0
# 43715     43716  2022-06-05    Serbia       Slovenia         4.0         1.0
# 43990     43991  2022-09-24    Serbia         Sweden         4.0         1.0
#
#                          tournament      city     country  neutral
# 19130                      Friendly  Belgrade  Yugoslavia    False
# 19238                      Friendly  Belgrade  Yugoslavia    False
# 19790                      Friendly  Belgrade  Yugoslavia    False
# 19830  FIFA World Cup qualification  Belgrade  Yugoslavia     True
# 19948  FIFA World Cup qualification  Belgrade  Yugoslavia     True
# ...                             ...       ...         ...      ...
# 43094  FIFA World Cup qualification  Belgrade      Serbia    False
# 43138                      Friendly  Belgrade      Serbia    False
# 43651           UEFA Nations League  Belgrade      Serbia    False
# 43715           UEFA Nations League  Belgrade      Serbia    False
# 43990           UEFA Nations League  Belgrade      Serbia    False
#
# [119 rows x 10 columns]

# %%
matches_trimmed.loc[matches['home_team']=='Montenegro']
# Out:
#        match_id        date   home_team               away_team  home_score  \
# 29373     29374  2007-03-24  Montenegro                 Hungary         2.0
# 29788     29789  2007-08-22  Montenegro                Slovenia         1.0
# 29915     29916  2007-09-12  Montenegro                  Sweden         1.0
# 30387     30388  2008-03-26  Montenegro                  Norway         3.0
# 30493     30494  2008-05-27  Montenegro              Kazakhstan         3.0
# ...         ...         ...         ...                     ...         ...
# 43542     43543  2022-03-28  Montenegro                  Greece         1.0
# 43698     43699  2022-06-04  Montenegro                 Romania         2.0
# 43845     43846  2022-06-11  Montenegro  Bosnia and Herzegovina         1.0
# 44012     44013  2022-09-26  Montenegro                 Finland         0.0
# 44110     44111  2022-11-17  Montenegro                Slovakia         2.0
#
#        away_score           tournament       city     country  neutral
# 29373         1.0             Friendly  Podgorica  Montenegro    False
# 29788         1.0             Friendly  Podgorica  Montenegro    False
# 29915         2.0             Friendly  Podgorica  Montenegro    False
# 30387         1.0             Friendly  Podgorica  Montenegro    False
# 30493         0.0             Friendly  Podgorica  Montenegro    False
# ...           ...                  ...        ...         ...      ...
# 43542         0.0             Friendly  Podgorica  Montenegro    False
# 43698         0.0  UEFA Nations League  Podgorica  Montenegro    False
# 43845         1.0  UEFA Nations League  Podgorica  Montenegro    False
# 44012         2.0  UEFA Nations League  Podgorica  Montenegro    False
# 44110         2.0             Friendly  Podgorica  Montenegro    False
#
# [69 rows x 10 columns]

# %%
matches_trimmed.loc[matches['home_team']=='Serbia and Montenegro'].head(20)
# Out:
# Empty DataFrame
# Columns: [match_id, date, home_team, away_team, home_score, away_score, tournament, city, country, neutral]
# Index: []

# %%
matches_trimmed['home_team'].value_counts().tail(30)
# Out:
# Tibet                        4
# Darfur                       4
# Republic of St. Pauli        4
# Canary Islands               4
# Kiribati                     3
# Găgăuzia                     3
# Western Sahara               3
# Gozo                         3
# Arameans Suryoye             3
# Matabeleland                 2
# Micronesia                   2
# Somaliland                   2
# Felvidék                     2
# Parishes of Jersey           2
# Yoruba Nation                2
# Biafra                       2
# Vatican City                 2
# Mapuche                      2
# Raetia                       2
# Cascadia                     2
# Saint Helena                 1
# Chameria                     1
# Palau                        1
# Kabylia                      1
# Saint Pierre and Miquelon    1
# Romani people                1
# Sark                         1
# Silesia                      1
# Madrid                       1
# Aymara                       1
# Name: home_team, dtype: int64

# %%
matches_trimmed.loc[matches_trimmed['country']=='Czechoslovakia']
# Out:
# Empty DataFrame
# Columns: [match_id, date, home_team, away_team, home_score, away_score, tournament, city, country, neutral]
# Index: []

# %%
matches.loc[matches['country']=='Yugoslavia']
# Out:
#        match_id        date   home_team       away_team  home_score  \
# 642         643  1922-06-08  Yugoslavia         Romania         1.0
# 649         650  1922-06-28  Yugoslavia  Czechoslovakia         4.0
# 669         670  1922-10-01  Yugoslavia          Poland         1.0
# 780         781  1924-02-10  Yugoslavia         Austria         1.0
# 840         841  1924-09-28  Yugoslavia  Czechoslovakia         0.0
# ...         ...         ...         ...             ...         ...
# 24566     24567  2001-08-15      Serbia   Faroe Islands         2.0
# 24638     24639  2001-09-05      Serbia        Slovenia         1.0
# 24688     24689  2001-10-06      Serbia      Luxembourg         6.0
# 25055     25056  2002-04-17      Serbia       Lithuania         4.0
# 25427     25428  2002-10-16      Serbia         Finland         2.0
#
#        away_score                    tournament       city     country  \
# 642           2.0                      Friendly   Belgrade  Yugoslavia
# 649           3.0                      Friendly     Zagreb  Yugoslavia
# 669           3.0                      Friendly     Zagreb  Yugoslavia
# 780           4.0                      Friendly     Zagreb  Yugoslavia
# 840           2.0                      Friendly     Zagreb  Yugoslavia
# ...           ...                           ...        ...         ...
# 24566         0.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 24638         1.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 24688         2.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 25055         1.0                      Friendly  Smederevo  Yugoslavia
# 25427         0.0       UEFA Euro qualification   Belgrade  Yugoslavia
#
#        neutral
# 642      False
# 649      False
# 669      False
# 780      False
# 840      False
# ...        ...
# 24566     True
# 24638     True
# 24688     True
# 25055    False
# 25427    False
#
# [217 rows x 10 columns]

# %%
matches_trimmed.loc[(matches_trimmed['date'] > '1990-01-01') & (matches_trimmed['country']=='Yugoslavia')]
# Out:
#        match_id        date home_team            away_team  home_score  \
# 19130     19131  1995-03-31    Serbia              Uruguay         1.0
# 19238     19239  1995-05-31    Serbia               Russia         1.0
# 19790     19791  1996-03-27    Serbia              Romania         1.0
# 19830     19831  1996-04-24    Serbia        Faroe Islands         3.0
# 19948     19949  1996-06-02    Serbia                Malta         6.0
# 20360     20361  1996-11-10    Serbia       Czech Republic         1.0
# 20609     20610  1997-03-12    Serbia               Russia         0.0
# 20781     20782  1997-04-30    Serbia                Spain         1.0
# 20877     20878  1997-06-08    Serbia             Slovakia         2.0
# 21269     21270  1997-11-15    Serbia              Hungary         5.0
# 21544     21545  1998-04-22    Serbia          South Korea         3.0
# 21597     21598  1998-05-29    Serbia              Nigeria         3.0
# 21814     21815  1998-09-02    Serbia          Switzerland         1.0
# 22014     22015  1998-11-18    Serbia  Republic of Ireland         1.0
# 22551     22552  1999-08-18    Serbia              Croatia         0.0
# 22587     22588  1999-09-05    Serbia      North Macedonia         3.0
# 23020     23021  2000-03-28    Serbia             China PR         1.0
# 24042     24043  2001-03-24    Serbia          Switzerland         1.0
# 24191     24192  2001-04-25    Serbia               Russia         0.0
# 24566     24567  2001-08-15    Serbia        Faroe Islands         2.0
# 24638     24639  2001-09-05    Serbia             Slovenia         1.0
# 24688     24689  2001-10-06    Serbia           Luxembourg         6.0
# 25055     25056  2002-04-17    Serbia            Lithuania         4.0
# 25427     25428  2002-10-16    Serbia              Finland         2.0
#
#        away_score                    tournament       city     country  \
# 19130         0.0                      Friendly   Belgrade  Yugoslavia
# 19238         2.0                      Friendly   Belgrade  Yugoslavia
# 19790         0.0                      Friendly   Belgrade  Yugoslavia
# 19830         1.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 19948         0.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 20360         0.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 20609         0.0                      Friendly   Belgrade  Yugoslavia
# 20781         1.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 20877         0.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 21269         0.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 21544         1.0                      Friendly   Belgrade  Yugoslavia
# 21597         0.0                      Friendly   Belgrade  Yugoslavia
# 21814         1.0                      Friendly        Niš  Yugoslavia
# 22014         0.0       UEFA Euro qualification   Belgrade  Yugoslavia
# 22551         0.0       UEFA Euro qualification   Belgrade  Yugoslavia
# 22587         1.0       UEFA Euro qualification   Belgrade  Yugoslavia
# 23020         0.0                      Friendly   Belgrade  Yugoslavia
# 24042         1.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 24191         1.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 24566         0.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 24638         1.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 24688         2.0  FIFA World Cup qualification   Belgrade  Yugoslavia
# 25055         1.0                      Friendly  Smederevo  Yugoslavia
# 25427         0.0       UEFA Euro qualification   Belgrade  Yugoslavia
#
#        neutral
# 19130    False
# 19238    False
# 19790    False
# 19830     True
# 19948     True
# 20360     True
# 20609    False
# 20781     True
# 20877     True
# 21269     True
# 21544    False
# 21597    False
# 21814    False
# 22014    False
# 22551    False
# 22587    False
# 23020    False
# 24042     True
# 24191     True
# 24566     True
# 24638     True
# 24688     True
# 25055    False
# 25427    False
