# %%
import pandas as pd

# %%
country_codes = pd.read_csv('./data/country_codes.csv')
rankings = pd.read_csv('./data/fifa_rankings.csv')
matches = pd.read_csv('./data/matches.csv')

# %%
matches
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 0             1  1872-11-30       Scotland       England         0.0
# 1             2  1873-03-08        England      Scotland         4.0
# 2             3  1874-03-07       Scotland       England         2.0
# 3             4  1875-03-06        England      Scotland         2.0
# 4             5  1876-03-04       Scotland       England         3.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament       city   country  neutral
# 0             0.0        Friendly    Glasgow  Scotland    False
# 1             2.0        Friendly     London   England    False
# 2             1.0        Friendly    Glasgow  Scotland    False
# 3             2.0        Friendly     London   England    False
# 4             0.0        Friendly    Glasgow  Scotland    False
# ...           ...             ...        ...       ...      ...
# 44159         2.0  FIFA World Cup       Doha     Qatar     True
# 44160         2.0  FIFA World Cup  Al Rayyan     Qatar     True
# 44161         1.0  FIFA World Cup  Al Rayyan     Qatar     True
# 44162         2.0  FIFA World Cup     Lusail     Qatar     True
# 44163         0.0  FIFA World Cup  Al Rayyan     Qatar     True
#
# [44164 rows x 10 columns]

# %%
rankings['rank_date'].iloc[0]
# Out:
# '1992-12-31'

# %%
# Trim matches
matches_trimmed = matches.drop(matches[matches['date'] <= rankings['rank_date'].iloc[0]].index)
matches_trimmed
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 17697     17698  1993-01-01          Ghana          Mali         1.0
# 17698     17699  1993-01-02          Gabon  Burkina Faso         1.0
# 17699     17700  1993-01-02         Kuwait       Lebanon         2.0
# 17700     17701  1993-01-03   Burkina Faso          Mali         1.0
# 17701     17702  1993-01-03          Gabon         Ghana         2.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament         city country  neutral
# 17697         1.0        Friendly   Libreville   Gabon     True
# 17698         1.0        Friendly   Libreville   Gabon    False
# 17699         0.0        Friendly  Kuwait City  Kuwait    False
# 17700         0.0        Friendly   Libreville   Gabon     True
# 17701         3.0        Friendly   Libreville   Gabon    False
# ...           ...             ...          ...     ...      ...
# 44159         2.0  FIFA World Cup         Doha   Qatar     True
# 44160         2.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44161         1.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44162         2.0  FIFA World Cup       Lusail   Qatar     True
# 44163         0.0  FIFA World Cup    Al Rayyan   Qatar     True
#
# [26467 rows x 10 columns]

# %%
rankings
# Out:
#        rank country_abrv  total_points  previous_points  rank_change  \
# 0         1          GER         57.00             0.00            0
# 1        96          SYR         11.00             0.00            0
# 2        97          BFA         11.00             0.00            0
# 3        99          LVA         10.00             0.00            0
# 4       100          BDI         10.00             0.00            0
# ...     ...          ...           ...              ...          ...
# 63894    74          SLV       1330.51          1333.48            3
# 63895    75          OMA       1320.29          1323.03            0
# 63896    76          ISR       1316.55          1316.35            0
# 63897    78          GEO       1307.34          1296.46           -4
# 63898   211          SMR        762.22           763.82            0
#
#       confederation   rank_date          team
# 0              UEFA  1992-12-31       Germany
# 1               AFC  1992-12-31         Syria
# 2               CAF  1992-12-31  Burkina Faso
# 3              UEFA  1992-12-31        Latvia
# 4               CAF  1992-12-31       Burundi
# ...             ...         ...           ...
# 63894      CONCACAF  2022-10-06   El Salvador
# 63895           AFC  2022-10-06          Oman
# 63896          UEFA  2022-10-06        Israel
# 63897          UEFA  2022-10-06       Georgia
# 63898          UEFA  2022-10-06    San Marino
#
# [63899 rows x 8 columns]

# %%
# Countries in Rankings but NOT in Matches


# first see which countries are in rankings but not in matches
countries_in_rankings_not_in_matches = list(set(rankings['team'].unique()) - set(matches_trimmed['home_team'].unique()))
countries_in_rankings_not_in_matches

# # Create series with all countries in matches and the number of matches
# countries_list_matches = rankings['team'].value_counts()

# # Then filter the  list of matches using the countries that are in matches but not in federation
# print((countries_list_matches.loc[countries_in_rankings_not_in_matches]).sort_values(ascending=False))
# Out:
# ['U.S. Virgin Islands', 'China', 'Chinese Taipei']

# %%
list(set(rankings['team'].unique()) - set(matches_trimmed['away_team'].unique()))
# Out:
# ['U.S. Virgin Islands', 'China', 'Chinese Taipei']

# %% [markdown]
# ### 3 Countries that are in RANKINGS do not show up in MATCHES
# ### Because they have different names in MATCHES

# %%
# Countries IN Matches but NOT IN RANKINGS
# We are looking for China, Taiwan (Chinese Taipei) and Unites States Virgin Islands (U.S. Virgin Islands)
# These are popular countries, they will for sure have more matches to them

# first see which countries are in matches but not in rankings (there will be more than 3, MATCHES has non-fifa countries as well)
countries_in_matches_not_in_rankings = list(set(matches_trimmed['home_team'].unique()) - set(rankings['team'].unique()))

# Create series with all countries in MATCHES and the number of matches
countries_list = matches_trimmed['home_team'].value_counts()

# Then filter the list of matches using the countries that are in MATCHES but not in RANKINGS (first 25 with most matches)
print((countries_list.loc[countries_in_matches_not_in_rankings]).sort_values(ascending=False).head(20))
# Out:
# China PR                        212
# Martinique                       91
# Guadeloupe                       71
# French Guiana                    48
# Jersey                           46
# Guernsey                         37
# Padania                          28
# Zanzibar                         28
# United States Virgin Islands     26
# Greenland                        26
# Ynys Môn                         25
# Basque Country                   24
# Isle of Wight                    24
# Catalonia                        23
# Taiwan                           22
# Isle of Man                      22
# Northern Cyprus                  20
# Åland Islands                    20
# Shetland                         20
# Gotland                          20
# Name: home_team, dtype: int64

# %%
teams_to_replace = ['United States Virgin Islands','China PR','Taiwan']
print('Teams to replace: \n',teams_to_replace, '\nTo be replaced by: \n',countries_in_rankings_not_in_matches)
# Out:
# Teams to replace:
#  ['United States Virgin Islands', 'China PR', 'Taiwan']
# To be replaced by:
#  ['U.S. Virgin Islands', 'China', 'Chinese Taipei']

# %%
matches_trimmed_modif = matches_trimmed.copy()

# %%
matches_trimmed_modif['home_team'] = matches_trimmed['home_team'].replace(teams_to_replace,countries_in_rankings_not_in_matches)
matches_trimmed_modif['away_team'] = matches_trimmed['away_team'].replace(teams_to_replace,countries_in_rankings_not_in_matches)
matches_trimmed_modif['country'] = matches_trimmed['country'].replace(teams_to_replace,countries_in_rankings_not_in_matches)

# %%
matches_trimmed_modif
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 17697     17698  1993-01-01          Ghana          Mali         1.0
# 17698     17699  1993-01-02          Gabon  Burkina Faso         1.0
# 17699     17700  1993-01-02         Kuwait       Lebanon         2.0
# 17700     17701  1993-01-03   Burkina Faso          Mali         1.0
# 17701     17702  1993-01-03          Gabon         Ghana         2.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament         city country  neutral
# 17697         1.0        Friendly   Libreville   Gabon     True
# 17698         1.0        Friendly   Libreville   Gabon    False
# 17699         0.0        Friendly  Kuwait City  Kuwait    False
# 17700         0.0        Friendly   Libreville   Gabon     True
# 17701         3.0        Friendly   Libreville   Gabon    False
# ...           ...             ...          ...     ...      ...
# 44159         2.0  FIFA World Cup         Doha   Qatar     True
# 44160         2.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44161         1.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44162         2.0  FIFA World Cup       Lusail   Qatar     True
# 44163         0.0  FIFA World Cup    Al Rayyan   Qatar     True
#
# [26467 rows x 10 columns]

# %%
# test
list(set(rankings['team'].unique()) - set(matches_trimmed_modif['home_team'].unique()))
# all teams from RANKINGS have their counterpart in MATCHES
# Out:
# []

# %%
# But there are still non-fifa countries in matches
nonfifa_still_in_matches = list(set(matches_trimmed_modif['home_team'].unique()) - set(rankings['team'].unique()))
print('Non-fifa teams in international matches: \n', nonfifa_still_in_matches)
# Out:
# Non-fifa teams in international matches:
#  ['Ynys Môn', 'French Guiana', 'Barawa', 'Padania', 'Kernow', 'Republic of St. Pauli', 'Tibet', 'Ellan Vannin', 'Sápmi', 'Tamil Eelam', 'Cascadia', 'Guernsey', 'Galicia', 'Raetia', 'Gozo', 'Western Sahara', 'Alderney', 'Iraqi Kurdistan', 'Gotland', 'Hitra', 'Saare County', 'Artsakh', 'Madrid', 'Silesia', 'Kabylia', 'Menorca', 'Occitania', 'Matabeleland', 'Jersey', 'Abkhazia', 'South Ossetia', 'Zanzibar', 'Bonaire', 'Corsica', 'Shetland', 'Canary Islands', 'Brittany', 'Northern Mariana Islands', 'Rhodes', 'Vatican City', 'Kiribati', 'Biafra', 'Găgăuzia', 'Aymara', 'Greenland', 'Arameans Suryoye', 'Guadeloupe', 'Panjab', 'Western Isles', 'Felvidék', 'Isle of Wight', 'Saint Helena', 'Saint Martin', 'Martinique', 'Frøya', 'Åland Islands', 'Romani people', 'Provence', 'Isle of Man', 'Andalusia', 'Chameria', 'Monaco', 'Palau', 'Parishes of Jersey', 'United Koreans in Japan', 'Western Armenia', 'Falkland Islands', 'Sint Maarten', 'Mayotte', 'Tuvalu', 'Micronesia', 'Northern Cyprus', 'Székely Land', 'County of Nice', 'Saint Pierre and Miquelon', 'Mapuche', 'Darfur', 'Somaliland', 'Réunion', 'Kárpátalja', 'Basque Country', 'Orkney', 'Yoruba Nation', 'Sark', 'Yorkshire', 'Chagos Islands', 'Catalonia']

# %%
# We can delete all of these matches from the record so that only fifa matches are shown
fifa_matches = matches_trimmed_modif.copy()

# %%
fifa_matches.drop(fifa_matches[fifa_matches['home_team'].isin(nonfifa_still_in_matches)].index, inplace=True)

# %%
fifa_matches
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 17697     17698  1993-01-01          Ghana          Mali         1.0
# 17698     17699  1993-01-02          Gabon  Burkina Faso         1.0
# 17699     17700  1993-01-02         Kuwait       Lebanon         2.0
# 17700     17701  1993-01-03   Burkina Faso          Mali         1.0
# 17701     17702  1993-01-03          Gabon         Ghana         2.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament         city country  neutral
# 17697         1.0        Friendly   Libreville   Gabon     True
# 17698         1.0        Friendly   Libreville   Gabon    False
# 17699         0.0        Friendly  Kuwait City  Kuwait    False
# 17700         0.0        Friendly   Libreville   Gabon     True
# 17701         3.0        Friendly   Libreville   Gabon    False
# ...           ...             ...          ...     ...      ...
# 44159         2.0  FIFA World Cup         Doha   Qatar     True
# 44160         2.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44161         1.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44162         2.0  FIFA World Cup       Lusail   Qatar     True
# 44163         0.0  FIFA World Cup    Al Rayyan   Qatar     True
#
# [25468 rows x 10 columns]

# %%
fifa_matches.drop(fifa_matches[fifa_matches['away_team'].isin(nonfifa_still_in_matches)].index, inplace=True)

# %%
fifa_matches
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 17697     17698  1993-01-01          Ghana          Mali         1.0
# 17698     17699  1993-01-02          Gabon  Burkina Faso         1.0
# 17699     17700  1993-01-02         Kuwait       Lebanon         2.0
# 17700     17701  1993-01-03   Burkina Faso          Mali         1.0
# 17701     17702  1993-01-03          Gabon         Ghana         2.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament         city country  neutral
# 17697         1.0        Friendly   Libreville   Gabon     True
# 17698         1.0        Friendly   Libreville   Gabon    False
# 17699         0.0        Friendly  Kuwait City  Kuwait    False
# 17700         0.0        Friendly   Libreville   Gabon     True
# 17701         3.0        Friendly   Libreville   Gabon    False
# ...           ...             ...          ...     ...      ...
# 44159         2.0  FIFA World Cup         Doha   Qatar     True
# 44160         2.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44161         1.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44162         2.0  FIFA World Cup       Lusail   Qatar     True
# 44163         0.0  FIFA World Cup    Al Rayyan   Qatar     True
#
# [25103 rows x 10 columns]

# %%
fifa_matches.drop(fifa_matches[fifa_matches['country'].isin(nonfifa_still_in_matches)].index, inplace=True)

# %%
fifa_matches
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 17697     17698  1993-01-01          Ghana          Mali         1.0
# 17698     17699  1993-01-02          Gabon  Burkina Faso         1.0
# 17699     17700  1993-01-02         Kuwait       Lebanon         2.0
# 17700     17701  1993-01-03   Burkina Faso          Mali         1.0
# 17701     17702  1993-01-03          Gabon         Ghana         2.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44164  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament         city country  neutral
# 17697         1.0        Friendly   Libreville   Gabon     True
# 17698         1.0        Friendly   Libreville   Gabon    False
# 17699         0.0        Friendly  Kuwait City  Kuwait    False
# 17700         0.0        Friendly   Libreville   Gabon     True
# 17701         3.0        Friendly   Libreville   Gabon    False
# ...           ...             ...          ...     ...      ...
# 44159         2.0  FIFA World Cup         Doha   Qatar     True
# 44160         2.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44161         1.0  FIFA World Cup    Al Rayyan   Qatar     True
# 44162         2.0  FIFA World Cup       Lusail   Qatar     True
# 44163         0.0  FIFA World Cup    Al Rayyan   Qatar     True
#
# [25067 rows x 10 columns]

# %%
fifa_matches.reset_index(drop=True, inplace=True)

# %%
fifa_matches.drop(columns='match_id', inplace=True)

# %%
fifa_matches.insert(0,"match_id", fifa_matches.index+1)

# %%
fifa_matches
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 0             1  1993-01-01          Ghana          Mali         1.0
# 1             2  1993-01-02          Gabon  Burkina Faso         1.0
# 2             3  1993-01-02         Kuwait       Lebanon         2.0
# 3             4  1993-01-03   Burkina Faso          Mali         1.0
# 4             5  1993-01-03          Gabon         Ghana         2.0
# ...         ...         ...            ...           ...         ...
# 25062     25063  2022-11-21        Senegal   Netherlands         0.0
# 25063     25064  2022-11-21        England          Iran         6.0
# 25064     25065  2022-11-21  United States         Wales         1.0
# 25065     25066  2022-11-22      Argentina  Saudi Arabia         1.0
# 25066     25067  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament         city country  neutral
# 0             1.0        Friendly   Libreville   Gabon     True
# 1             1.0        Friendly   Libreville   Gabon    False
# 2             0.0        Friendly  Kuwait City  Kuwait    False
# 3             0.0        Friendly   Libreville   Gabon     True
# 4             3.0        Friendly   Libreville   Gabon    False
# ...           ...             ...          ...     ...      ...
# 25062         2.0  FIFA World Cup         Doha   Qatar     True
# 25063         2.0  FIFA World Cup    Al Rayyan   Qatar     True
# 25064         1.0  FIFA World Cup    Al Rayyan   Qatar     True
# 25065         2.0  FIFA World Cup       Lusail   Qatar     True
# 25066         0.0  FIFA World Cup    Al Rayyan   Qatar     True
#
# [25067 rows x 10 columns]

# %%
fifa_matches.to_csv('./data/fifa_matches.csv', index=False)

# %%
list(set(fifa_matches['home_team'].unique()) - set(country_codes['team'].unique()))
# Out:
# []

# %%
list(set(country_codes['team'].unique()) - set(fifa_matches['home_team'].unique()))
# Out:
# []
