# %%
import pandas as pd

# %%
matches = pd.read_csv('./data/matches.csv')
federations = pd.read_csv('./data/federations.csv')
rankings = pd.read_csv('./data/fifa_rankings.csv')

# %%
matches
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 0             1  1872-11-30       Scotland       England         0.0
# 1             2  1873-03-08        England      Scotland         4.0
# 2             3  1874-03-07       Scotland       England         2.0
# 3             4  1875-03-06        England      Scotland         2.0
# 4             5  1876-03-04       Scotland       England         3.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44165  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament       city   country  neutral
# 0             0.0        Friendly    Glasgow  Scotland    False
# ...

# %%
federations
# Out:
#     code               name  founded  FIFA_affiliation  \
# 0    AUS          Australia     1961            1963.0
# 1    BRU  Brunei Darussalam     1952            1972.0
# 2    CAM           Cambodia     1933            1954.0
# 3    LAO               Laos     1951            1952.0
# 4    INA          Indonesia     1930            1952.0
# ..   ...                ...      ...               ...
# 217  SWE             Sweden     1904            1904.0
# 218  SUI        Switzerland     1895            1904.0
# 219  TUR             Turkey     1923            1923.0
# 220  UKR            Ukraine     1991            1992.0
# 221  WAL              Wales     1876            1910.0
#
#      confederation_affiliation regional confederation  IOC_member
# 0                         2006      AFF           AFC        True
# 1                         1969      AFF           AFC        True
# 2                         1954      AFF           AFC        True
# ...

# %%
rankings
# Out:
#        rank  country_full country_abrv  total_points  previous_points  \
# 0         1       Germany          GER         57.00             0.00
# 1        96         Syria          SYR         11.00             0.00
# 2        97  Burkina Faso          BFA         11.00             0.00
# 3        99        Latvia          LVA         10.00             0.00
# 4       100       Burundi          BDI         10.00             0.00
# ...     ...           ...          ...           ...              ...
# 63911    74   El Salvador          SLV       1330.51          1333.48
# 63912    75          Oman          OMA       1320.29          1323.03
# 63913    76        Israel          ISR       1316.55          1316.35
# 63914    78       Georgia          GEO       1307.34          1296.46
# 63915   211    San Marino          SMR        762.22           763.82
#
#        rank_change confederation   rank_date
# 0                0          UEFA  1992-12-31
# ...

# %%
# Now check to see which countries remain in matches that are not part of fifa


# first see which countries are in matches but not in federations
countries_in_matches_not_in_federations = list(set(matches['home_team'].unique()) - set(federations['name'].unique()))

# Create series with all countries in matches and the number of matches
countries_list_matches_new = matches['home_team'].value_counts()

# Then filter the  list of matches using the countries that are in matches but not in federation
print((countries_list_matches_new.loc[countries_in_matches_not_in_federations]).sort_values(ascending=False).head(30))

# This way we see how we should reformat the countries from confederations
# Out:
# Czechoslovakia      231
# Yugoslavia          190
# German DR           132
# Vietnam Republic     49
# Jersey               48
# Catalonia            39
# Guernsey             37
# Basque Country       33
# Greenland            30
# Ynys Môn             29
# Brunei               28
# Padania              28
# Åland Islands        27
# Isle of Wight        26
# Shetland             22
# Isle of Man          22
# Northern Cyprus      22
# Gotland              20
# Sápmi                18
# Abkhazia             18
# Saare County         15
# Iraqi Kurdistan      13
# Orkney               12
# Andalusia            12
# Frøya                12
# Barawa               11
# Western Isles        11
# Rhodes               11
# Menorca              11
# Falkland Islands     11
# Name: home_team, dtype: int64

# %%
# Now check to see which countries remain in rankings that are not part of fifa


# first see which countries are in matches but not in federations
countries_in_rankings_not_in_federations = list(set(rankings['country_full'].unique()) - set(federations['name'].unique()))

# Create series with all countries in matches and the number of matches
countries_list_rankings = rankings['country_full'].value_counts()

# Then filter the  list of matches using the countries that are in matches but not in federation
print((countries_list_rankings.loc[countries_in_rankings_not_in_federations]).sort_values(ascending=False))

# This way we see how we should reformat the countries from confederations
# Out:
# Yugoslavia              102
# Netherlands Antilles     44
# Czechoslovakia            6
# Name: country_full, dtype: int64

# %%
countries_in_rankings_not_in_federations
# Out:
# ['Netherlands Antilles', 'Czechoslovakia', 'Yugoslavia']

# %%
rankings_current_fifa = rankings[~rankings['country_full'].isin(countries_in_rankings_not_in_federations)]

# %%
rankings_current_fifa
# Out:
#        rank  country_full country_abrv  total_points  previous_points  \
# 0         1       Germany          GER         57.00             0.00
# 1        96         Syria          SYR         11.00             0.00
# 2        97  Burkina Faso          BFA         11.00             0.00
# 3        99        Latvia          LVA         10.00             0.00
# 4       100       Burundi          BDI         10.00             0.00
# ...     ...           ...          ...           ...              ...
# 63911    74   El Salvador          SLV       1330.51          1333.48
# 63912    75          Oman          OMA       1320.29          1323.03
# 63913    76        Israel          ISR       1316.55          1316.35
# 63914    78       Georgia          GEO       1307.34          1296.46
# 63915   211    San Marino          SMR        762.22           763.82
#
#        rank_change confederation   rank_date
# 0                0          UEFA  1992-12-31
# ...

# %%
countries_fifa_not_in_rankings_test = list(set(federations['name'].unique()) - set(rankings_current_fifa['country_full'].unique()))
countries_fifa_not_in_rankings_test
# Out:
# ['Zanzibar',
#  'Tuvalu',
#  'Sint Maarten',
#  'French Guiana',
#  'Guadeloupe',
#  'Bonaire',
#  'Réunion',
#  'Northern Mariana Islands',
#  'Kiribati',
#  'Martinique',
#  'Saint Martin']

# %%
federations_current_fifa = federations[~federations['name'].isin(countries_fifa_not_in_rankings_test)]

# %%
federations_current_fifa
# Out:
#     code               name  founded  FIFA_affiliation  \
# 0    AUS          Australia     1961            1963.0
# 1    BRU  Brunei Darussalam     1952            1972.0
# 2    CAM           Cambodia     1933            1954.0
# 3    LAO               Laos     1951            1952.0
# 4    INA          Indonesia     1930            1952.0
# ..   ...                ...      ...               ...
# 217  SWE             Sweden     1904            1904.0
# 218  SUI        Switzerland     1895            1904.0
# 219  TUR             Turkey     1923            1923.0
# 220  UKR            Ukraine     1991            1992.0
# 221  WAL              Wales     1876            1910.0
#
#      confederation_affiliation regional confederation  IOC_member
# 0                         2006      AFF           AFC        True
# 1                         1969      AFF           AFC        True
# 2                         1954      AFF           AFC        True
# ...

# %%
countries_fifa_not_in_rankings_test2 = list(set(federations_current_fifa['name'].unique()) - set(rankings_current_fifa['country_full'].unique()))
countries_fifa_not_in_rankings_test2
# Out:
# []

# %%
countries_fifa_not_in_rankings_test3 = list(set(rankings_current_fifa['country_full'].unique()) - set(federations_current_fifa['name'].unique()) )
countries_fifa_not_in_rankings_test3
# Out:
# []

# %%
# Now check to see which countries remain in rankings that are not part of fifa


# first see which countries are in matches but not in federations
countries_in_matches_not_in_federations = list(set(matches['home_team'].unique()) - set(federations['name'].unique()))

# Create series with all countries in matches and the number of matches
countries_list_matches = matches['home_team'].value_counts()

# Then filter the  list of matches using the countries that are in matches but not in federation
print((countries_list_matches.loc[countries_in_matches_not_in_federations]).sort_values(ascending=False))

# This way we see how we should reformat the countries from confederations
# Out:
# Czechoslovakia               231
# Yugoslavia                   190
# German DR                    132
# Vietnam Republic              49
# Jersey                        48
#                             ...
# Saint Pierre and Miquelon      1
# Kabylia                        1
# Central Spain                  1
# Aymara                         1
# Sark                           1
# Name: home_team, Length: 89, dtype: int64

# %%
print(countries_in_matches_not_in_federations)
# Out:
# ['Sark', 'Brunei', 'Yoruba Nation', 'Alderney', 'Chameria', 'Tamil Eelam', 'Gotland', 'Kárpátalja', 'Isle of Wight', 'Frøya', 'Mayotte', 'Silesia', 'Madrid', 'Canary Islands', 'Kernow', 'Western Armenia', 'Saint Pierre and Miquelon', 'Guernsey', 'German DR', 'Darfur', 'North Vietnam', 'Padania', 'County of Nice', 'Yorkshire', 'Aymara', 'Tibet', 'Arameans Suryoye', 'Panjab', 'Mapuche', 'Falkland Islands', 'Northern Cyprus', 'Niue', 'Hitra', 'Găgăuzia', 'Czechoslovakia', 'United Koreans in Japan', 'South Ossetia', 'Occitania', 'Orkney', 'Micronesia', 'Barawa', 'Ellan Vannin', 'Rhodes', 'Chagos Islands', 'Brittany', 'Ynys Môn', 'Central Spain', 'Andalusia', 'Saare County', 'Gozo', 'Yugoslavia', 'Székely Land', 'Kabylia', 'Jersey', 'Saint Helena', 'Greenland', 'Menorca', 'Artsakh', 'Republic of St. Pauli', 'Shetland', 'Saarland', 'Romani people', 'Cascadia', 'Western Sahara', 'Abkhazia', 'Vatican City', 'Vietnam Republic', 'Palau', 'Åland Islands', 'Provence', 'Somaliland', 'Sápmi', 'Bas
# ...

# %%
matches_current_fifa = matches[~matches['home_team'].isin(countries_in_matches_not_in_federations)]

# %%
matches_current_fifa
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 0             1  1872-11-30       Scotland       England         0.0
# 1             2  1873-03-08        England      Scotland         4.0
# 2             3  1874-03-07       Scotland       England         2.0
# 3             4  1875-03-06        England      Scotland         2.0
# 4             5  1876-03-04       Scotland       England         3.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44165  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament       city   country  neutral
# 0             0.0        Friendly    Glasgow  Scotland    False
# ...

# %%
matches_current_fifa2 = matches_current_fifa[~matches_current_fifa['away_team'].isin(countries_in_matches_not_in_federations)]

# %%
matches_current_fifa2
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 0             1  1872-11-30       Scotland       England         0.0
# 1             2  1873-03-08        England      Scotland         4.0
# 2             3  1874-03-07       Scotland       England         2.0
# 3             4  1875-03-06        England      Scotland         2.0
# 4             5  1876-03-04       Scotland       England         3.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44165  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament       city   country  neutral
# 0             0.0        Friendly    Glasgow  Scotland    False
# ...

# %%
matches_current_fifa3 = matches_current_fifa2[~matches_current_fifa2['country'].isin(countries_in_matches_not_in_federations)]

# %%
matches_current_fifa3
# Out:
#        match_id        date      home_team     away_team  home_score  \
# 0             1  1872-11-30       Scotland       England         0.0
# 1             2  1873-03-08        England      Scotland         4.0
# 2             3  1874-03-07       Scotland       England         2.0
# 3             4  1875-03-06        England      Scotland         2.0
# 4             5  1876-03-04       Scotland       England         3.0
# ...         ...         ...            ...           ...         ...
# 44159     44160  2022-11-21        Senegal   Netherlands         0.0
# 44160     44161  2022-11-21        England          Iran         6.0
# 44161     44162  2022-11-21  United States         Wales         1.0
# 44162     44163  2022-11-22      Argentina  Saudi Arabia         1.0
# 44163     44165  2022-11-22        Denmark       Tunisia         0.0
#
#        away_score      tournament       city   country  neutral
# 0             0.0        Friendly    Glasgow  Scotland    False
# ...

# %%
list(set(federations_current_fifa['name'].unique()) - set(matches_current_fifa3['home_team'].unique()))
# Out:
# ['Brunei Darussalam']

# %%
list(set(matches_current_fifa3['home_team'].unique()) - set(federations_current_fifa['name'].unique()))
# Out:
# ['Zanzibar',
#  'Tuvalu',
#  'Sint Maarten',
#  'French Guiana',
#  'Guadeloupe',
#  'Bonaire',
#  'Réunion',
#  'Northern Mariana Islands',
#  'Kiribati',
#  'Martinique',
#  'Saint Martin']

# %%
federations_current_fifa
# Out:
#     code               name  founded  FIFA_affiliation  \
# 0    AUS          Australia     1961            1963.0
# 1    BRU  Brunei Darussalam     1952            1972.0
# 2    CAM           Cambodia     1933            1954.0
# 3    LAO               Laos     1951            1952.0
# 4    INA          Indonesia     1930            1952.0
# ..   ...                ...      ...               ...
# 217  SWE             Sweden     1904            1904.0
# 218  SUI        Switzerland     1895            1904.0
# 219  TUR             Turkey     1923            1923.0
# 220  UKR            Ukraine     1991            1992.0
# 221  WAL              Wales     1876            1910.0
#
#      confederation_affiliation regional confederation  IOC_member
# 0                         2006      AFF           AFC        True
# 1                         1969      AFF           AFC        True
# 2                         1954      AFF           AFC        True
# ...
